# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df= pd.read_csv('housePrice.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 10 columns):
# Area           1259 non-null float64
# BHK            1259 non-null int64
# Bathroom       1257 non-null float64
# Furnishing     1254 non-null object
# Locality       1259 non-null object
# Parking        1226 non-null float64
# Status         1259 non-null object
# Transaction    1259 non-null object
# Type           1254 non-null object
# Price          1259 non-null int64
# dtypes: float64(3), int64(2), object(5)
# memory usage: 98.5+ KB

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df['Area'].value_counts().plot(kind='bar')
plt.title('Area')
plt.xlabel('Area')
plt.ylabel('Price')
plt.show()
sb.despine
# Out:
# <function seaborn.utils.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)>

# %%
plt.scatter(df.Price,df.Transaction)
plt.xlabel('Transaction')
plt.ylabel('Price')
plt.show()
sb.despine()

# %%
plt.scatter(df.Price,df.BHK)
plt.xlabel('BHK')
plt.ylabel('Price')
plt.show()
sb.despine()

# %%
plt.scatter(df.Price,df.Parking)
plt.xlabel('Parking')
plt.ylabel('Price')
plt.show()
sb.despine()

# %%
plt.scatter(df.Price,df.Status)
plt.xlabel('Status')
plt.ylabel('Price')
plt.show()
sb.despine()

# %%
plt.scatter(df.Price,df.Locality)
plt.xlabel('Locality')
plt.ylabel('Price')
plt.show()
sb.despine()

# %%
plt.scatter(df.Price,df.Bathroom)
plt.xlabel('Bathroom')
plt.ylabel('Price')
plt.show()
sb.despine()

# %%
train1= df

# %%
 from sklearn import linear_model
las=linear_model.Lasso(alpha=20.0,max_iter=1e5)

# %%
x_test=[[1600,3,1,'SemiFurnished','Rohini',1,'Ready_to_Move','Resale','Apartment'],[1600,5,1,'Furnished','Rohini',1,'Ready_to_Move','Resale','Apartment']]
predictions=las.predict(x_test)
print (predictions)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-34-95f6add781ff> in <module>
#       1 x_test=[[1600,3,1,'SemiFurnished','Rohini',1,'Ready_to_Move','Resale','Apartment'],[1600,5,1,'Furnished','Rohini',1,'Ready_to_Move','Resale','Apartment']]
# ----> 2 predictions=las.predict(x_test)
#       3 print (predictions)
#
# C:\Anaconda\lib\site-packages\sklearn\linear_model\base.py in predict(self, X)
#     219             Returns predicted values.
#     220         """
# --> 221         return self._decision_function(X)
#     222
#     223     _preprocess_data = staticmethod(_preprocess_data)
#
# C:\Anaconda\lib\site-packages\sklearn\linear_model\coordinate_descent.py in _decision_function(self, X)
#     788             The predicted decision function
#     789         """
# --> 790         check_is_fitted(self, 'n_iter_')
#     791         if sparse.isspmatrix(X):
# ...
